# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os

# Define the directory containing your images
image_directory = 'report/sketches'

# List of image filenames
image_filenames = [f for f in os.listdir(image_directory) if f.endswith(('.png', '.jpg', '.jpeg'))]

# Sort the images to ensure a consistent order
image_filenames.sort()

# Create a figure with two rows and five columns
fig, axes = plt.subplots(2, 5, figsize=(25, 10))

# Iterate through the list of images and add them to the subplot
for i, ax in enumerate(axes.flatten()):
    img = mpimg.imread(os.path.join(image_directory, image_filenames[i]))
    ax.imshow(img)
    ax.axis('off')  # Turn off axis

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()
